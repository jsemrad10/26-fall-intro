# %%
def hi_function(input):
    print(input)

hi_function('hi')

# %%
import random

def randomfunction():
    number = random.randint(0,5)
    print(number)
    guess = int(input('guess a number between 0 and 5: '))
    if number == guess:
        print('good job')
    elif number != guess: 
        print('you suck')

randomfunction()
